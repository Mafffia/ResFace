# %%
import cv2
import numpy as np
import insightface
from insightface.app import FaceAnalysis
from insightface.data import get_image as ins_get_image
from matplotlib import pyplot as plt

# %%
app = FaceAnalysis(allowed_modules=['detection']) # enable detection model only
app.prepare(ctx_id=0, det_size=(640, 640))
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /home/mafffia/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /home/mafffia/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/mafffia/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /home/mafffia/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /home/mafffia/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)

# %%
img = cv2.imread('test.jpg')
faces = app.get(img)

# %%
faces
# Out:
# [{'bbox': array([ 85.47469,  76.81839, 165.40952, 190.46407], dtype=float32),
#   'kps': array([[109.66368 , 118.162125],
#          [146.80638 , 116.46279 ],
#          [132.13588 , 137.413   ],
#          [113.007034, 157.01833 ],
#          [147.43106 , 155.405   ]], dtype=float32),
#   'det_score': 0.8473418}]

# %%
bbox = faces[0]['bbox']

# %%
y1,x1,y2,x2 = int(bbox[0]),int(bbox[1]),int(bbox[2]),int(bbox[3])
cropped_image = img[x1:x2,y1:y2]

# %%
# cv2.imshow('test',cropped_image)
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.imshow(np.flip(cropped_image, axis=-1) )

# %%
import os
# csv_path = '../src/util/detect.py'
from src.util import detect
# Out:
# 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/mafffia/Desktop/ResFace/insightface.ipynb Cell 9 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/mafffia/Desktop/ResFace/insightface.ipynb#ch0000008?line=0'>1</a> import os
#       <a href='vscode-notebook-cell:/home/mafffia/Desktop/ResFace/insightface.ipynb#ch0000008?line=1'>2</a> # csv_path = '../src/util/detect.py'
# ----> <a href='vscode-notebook-cell:/home/mafffia/Desktop/ResFace/insightface.ipynb#ch0000008?line=2'>3</a> from src.util import detect
#
# File ~/Desktop/ResFace/src/util/detect.py:167, in <module>
#     157     return ret_faces
#     159 # faces = det_mediapipe('..//selfie.jpg')
#     160 # print(len(faces))
#     161 # img = cv2.imread('selfie.jpg')
#    (...)
#     164 # cv2.waitKey(0)
#     165 # cv2.destroyAllWindows()
# --> 167 det_scrfd('test.jpg')
#
# ...

# %%
# Out:
# array([], shape=(0, 0, 3), dtype=uint8)
