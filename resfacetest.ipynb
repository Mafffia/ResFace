# %%
# test detect module
from src.util.detect import detect
import matplotlib.pyplot as plt
from src.util.similarity import get_face_align
from src.util.landmarks import  scrfd_landmarks
from insightface.app import FaceAnalysis

import cv2

# %%
app = FaceAnalysis(name='my',allowed_modules=['detection']) 
app.prepare(ctx_id=0, det_size=(240, 240))
img = cv2.imread('test.jpg')
faces = app.get(img)
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/my/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/my/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/my/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/my/r100.onnx recognition
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/mafffia/.insightface/models/my/scrfd_2.5g_kps.onnx detection [1, 3, 640, 640] 127.5 128.0
# set det-size: (240, 240)
# ...
# ---------------------------------------------------------------------------
# ...

# %%
plt.figure()

plt.subplot(1,4,1)
plt.imshow(detect('test.jpg')[0])
plt.axis('off')
plt.subplot(1,4,2)
plt.imshow(detect('test.jpg',method='retina')[0])
plt.axis('off')
plt.subplot(1,4,3)
plt.imshow(detect('test.jpg',method='scrfd')[0])
plt.axis('off')
plt.subplot(1,4,4)
plt.imshow(detect('test.jpg',method='mediapipe')[0])
plt.axis('off')
plt.show()
# Out:
# [[ 66  67 123 123]]
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/mafffia/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)

# %%
# real scrfd
detect('test.jpg',method='scrfd')[0]
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/mafffia/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)
# array([[[119, 102,  82],
#         [120, 100,  76],
# ...

# %%
plt.imshow(get_face_align(detect('test.jpg',method='retina')[0]))
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/mafffia/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (240, 240)
# ...

# %%
img = cv2.cvtColor(img_file, cv2.COLOR_RGB2BGR)

# %%
scrfd_landmarks(cv2.cvtColor(detect('test.jpg',method='mediapipe')[0], cv2.COLOR_RGB2BGR))
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/mafffia/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (240, 240)
# ...

# %%
plt.imshow(detect('test.jpg',method='scrfd')[0])
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/mafffia/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /Users/mafffia/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)

# %%
plt.imshow(detect('test.jpg',method='mediapipe')[0])
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
